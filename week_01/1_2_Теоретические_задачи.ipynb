# %% [markdown]
# # Задача 1.2.1
# https://stepik.org/lesson/234583/step/2
#
# Рассмотрим уравнение разделяющей поверхности: $< w ⃗ ,x ⃗ > + b =0 $. Исключим из рассмотрения случай $w ⃗ = 0$, $b = 0$. Выберите верные утверждения:
#
#
# * Пороговая функция активации всегда будет равна 1 с той стороны от разделяющей прямой, в которую указывает вектор w
#
# * У этого уравнения несчетное (более, чем счетное) множество решений (наборов значений, при которых уравнение является верным равенством) при числе измерений > 1
#
# * Уравнение задает гиперплоскость (прямую, плоскость, N-мерную плоскость)
#
# * Нулевой вектор $(x ⃗  = 0 ⃗)$ всегда является решением этого уравнения
#
# * Вектор w является нормалью к гиперплоскости, которая задана этим уравнением
#
# * Уравнение задает кривую второго порядка

# %%
# Пороговая функция активации всегда будет равна 1 с той стороны от разделяющей прямой, в которую указывает вектор w

# У этого уравнения несчетное (более, чем счетное) множество решений (наборов значений, при которых уравнение является верным равенством) при числе измерений > 1

# Уравнение задает гиперплоскость (прямую, плоскость, N-мерную плоскость)

# Вектор w является нормалью к гиперплоскости, которая задана этим уравнением

# %% [markdown]
# # Задача 1.2.3
# https://stepik.org/lesson/234583/step/3
#
# Чему равна производная сигмоидной функции активации? Выразите ответ через сигмоидную функцию.
#
# Сигмоиду $σ(x)$ обозначьте как $s(x)$. Пожалуйста, используйте именно такую форму сигмоиды, именно с таким аргументом (есть много других форм решения, которые не принимаются).
#
# Например, если бы верным ответом было бы выражение $
# 𝜎
# ′
# (
# 𝑥
# )
# =
# 10
# (
# 1
# +
# 𝜎
# (
# 𝑥
# )
# )
# σ
# ′
#  (x)=10(1+σ(x))$ (это не так), то запись ответа выглядела бы следующим образом: $10 * (1 + s(x))$
#
# Не забывайте в ответе писать явно знак умножения.

# %% [markdown]
# Сигмоидная функция активации, часто используемая в нейронных сетях, определяется как:
#
# $σ(x) = \frac{1}{1+e-x}$
#
# Чтобы найти её производную, сначала найдем её значение, а затем производную:
#
# 1. Пусть
#
# $y=σ(x)= \frac{1}{1+e-x}$.
#
# 2. Найдем производную $\frac{dy}{dx}$:
#
# $\frac{dy}{dx} = \frac{d}{dx} = (\frac{1}{1+e^{-x}})$
#
# Используем метод цепочки. Для этого сначала возьмём производную от функции вида
# $\frac{1}{u(x)}$:
#
# $\frac{d}{dx}(\frac{1}{u}) = -\frac{1}{u^2}*\frac{du}{dx}$
#
# В нашем случае $u=1+e^{-x}$. Найдём производную от $u$:
#
# $
# \frac{du}{dx} = \frac{d}{dx}(\frac{1}{1+e^{-x}}) = -e^{-x}
# $
#
# Подставим это в выражение для производной:
#
# $
# \frac{dy}{dx} = -\frac{1}{(1+e^{-x})^2} * (-e^{-x})
# $
#
# $
# \frac{dy}{dx} = \frac{e^{-x}}{(1+e^{-x})^2}
# $
#
# Теперь преобразуем это выражение через саму сигмоидную функцию $σ(x)$. Заметим, что:
#
# $σ(x) = \frac{1}{1+e^{-x}}$
#
# $1 - σ(x) = 1 - \frac{1}{1+e^{-x}} = \frac{1+e^{-x} - 1}{1+e^{-x}} = \frac{e^{-x}}{1+e^{-x}}$
#
# Следовательно:
#
# $
# σ(x)(1 - σ(x)) = \frac{1}{1+e^{-x}} * \frac{e^{-x}}{1+e^{-x}} = \frac{e^{-x}}{(1+e^{-x})^2}
# $
#
# Таким образом, производная сигмоидной функции активации равна:
#
# $
# σ'(x) = σ(x)(1 - σ(x))
# $

# %% [markdown]
# Сигмоидная функция активации, часто используемая в нейронных сетях, определяется как:
#
# $ \sigma(x) = \frac{1}{1 + e^{-x}} $
#
# Чтобы найти её производную, сначала найдем её значение, а затем производную:
#
# 1. Пусть $ y = \sigma(x) = \frac{1}{1 + e^{-x}} $.
#
# 2. Найдем производную $ \frac{dy}{dx} $:
#
# $ \frac{dy}{dx} = \frac{d}{dx} \left( \frac{1}{1 + e^{-x}} \right) $
#
# Используем метод цепочки. Для этого сначала возьмём производную от функции вида $ \frac{1}{u(x)} $:
#
# $ \frac{d}{dx} \left( \frac{1}{u} \right) = -\frac{1}{u^2} \cdot \frac{du}{dx} $
#
# В нашем случае $ u = 1 + e^{-x} $. Найдём производную от $ u $:
#
# $ \frac{du}{dx} = \frac{d}{dx} (1 + e^{-x}) = -e^{-x} $
#
# Подставим это в выражение для производной:
#
# $ \frac{dy}{dx} = -\frac{1}{(1 + e^{-x})^2} \cdot (-e^{-x}) $
#
# $ \frac{dy}{dx} = \frac{e^{-x}}{(1 + e^{-x})^2} $
#
# Теперь преобразуем это выражение через саму сигмоидную функцию $ \sigma(x) $. Заметим, что:
#
# $ \sigma(x) = \frac{1}{1 + e^{-x}} $
#
# $ 1 - \sigma(x) = 1 - \frac{1}{1 + e^{-x}} = \frac{1 + e^{-x} - 1}{1 + e^{-x}} = \frac{e^{-x}}{1 + e^{-x}} $
#
# Следовательно:
#
# $ \sigma(x)(1 - \sigma(x)) = \frac{1}{1 + e^{-x}} \cdot \frac{e^{-x}}{1 + e^{-x}} = \frac{e^{-x}}{(1 + e^{-x})^2} $
#
# Таким образом, производная сигмоидной функции активации равна:
#
# $ \sigma'(x) = \sigma(x)(1 - \sigma(x)) $

# %%
# 10 * (1 + s(x)) образец

s(x) * (1 - s(x))

# %% [markdown]
# # Задача 1.2.4
# https://stepik.org/lesson/234583/step/4

# %% [markdown]
# # Решение
# Функция гиперболического тангенса (tanh) является распространённой функцией активации в нейронных сетях. Её определение:
#
# $ \tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}} $
#
# Рассмотрим свойства этой функции:
#
# ### 1. Четность
# Функция гиперболического тангенса нечётная. Это значит, что $\tanh(-x) = -\tanh(x)$. Действительно, если подставить $-x$ в функцию:
#
# $ \tanh(-x) = \frac{e^{-x} - e^{x}}{e^{-x} + e^{x}} = -\frac{e^x - e^{-x}}{e^x + e^{-x}} = -\tanh(x) $
#
# ### 2. Монотонность возрастания
# Функция $\tanh(x)$ является монотонно возрастающей. Её производная:
#
# $ \frac{d}{dx} \tanh(x) = 1 - \tanh^2(x) $
#
# Всегда положительна для всех $x$, так как $ 1 - \tanh^2(x) \geq 0 $ для всех $x$.
#
# ### 3. Непрерывность
# Функция гиперболического тангенса непрерывна для всех значений $x$. Это значит, что для любого $a$ из области определения функции предел $\tanh(x)$ при $x \to a$ равен $\tanh(a)$:
#
# $ \lim_{x \to a} \tanh(x) = \tanh(a) $
#
# ### 4. Ограниченность
# Функция $\tanh(x)$ ограничена. Её значения лежат в интервале от -1 до 1:
#
# $ -1 \leq \tanh(x) \leq 1 $
#
# ### 5. Разрывы
# Функция $\tanh(x)$ не имеет разрывов. Она гладкая и непрерывная для всех $x$.
#
# ### Резюме
# - **Четность**: Нечётная ($\tanh(-x) = -\tanh(x)$).
# - **Монотонность возрастания**: Монотонно возрастающая.
# - **Непрерывность**: Непрерывная для всех $x$.
# - **Ограниченность**: Значения ограничены интервалом $[-1, 1]$.
# - **Разрывы**: Нет разрывов.
#
# Таким образом, гиперболический тангенс $\tanh(x)$ обладает важными свойствами, которые делают его полезным в качестве функции активации в нейронных сетях.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Определение функции гиперболического тангенса
def tanh(x):
    return np.tanh(x)

# Определение производной функции гиперболического тангенса
# def tanh_derivative(x):
#     return 1 - np.tanh(x)**2

# Тестовые данные для визуализации
x = np.linspace(-5, 5, 400)
y = tanh(x)
# y_prime = tanh_derivative(x)

# Визуализация функции гиперболического тангенса и её производной
plt.figure(figsize=(10, 5))

# Гиперболический тангенс
plt.subplot(1, 2, 1)
plt.plot(x, y, label='tanh(x)')
plt.title('Hyperbolic Tangent Function')
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.grid(True)
plt.legend()

# Производная гиперболического тангенса
# plt.subplot(1, 2, 2)
# plt.plot(x, y_prime, label="tanh'(x)", color='red')
# plt.title('Derivative of Hyperbolic Tangent Function')
# plt.xlabel('x')
# plt.ylabel("tanh'(x)")
# plt.grid(True)
# plt.legend()

# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 400)
y = np.tanh(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.title('Hyperbolic Tangent Function')
plt.grid(True)
plt.show()

# %%
# Функция tanh нечетная                 +
# Функция tanh монотонно возрастает     +
# При x = 0 функция tanh равна 0        +
# Функция tanh ограничена               +
# Функция tanh четная                   -
# Функция tanh имеет разрыв первого рода    -
# Функция tanh непрерывна               +

# %% [markdown]
# # Задача 2.1.6
# https://stepik.org/lesson/234583/step/6

# %% [markdown]
# # Решение
# $1 - tanh(x)^2$
